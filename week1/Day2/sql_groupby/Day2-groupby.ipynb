# %%
# %sql
CREATE TABLE Employee (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
department VARCHAR(50),
salary DECIMAL(10, 2),
joining_date DATE
);
INSERT INTO Employee (emp_id, emp_name, department, salary, joining_date) VALUES
(1, 'Karthik', 'HR', 60000.00, '2021-01-15'),
(2, 'Pratik', 'Finance', 70000.00, '2021-03-10'),
(3, 'Veer', 'HR', 55000.00, '2021-06-20'),
(4, 'Priya', 'Finance', 80000.00, '2022-01-05'),
(5, 'Ajay', 'Engineering', 75000.00, '2020-11-01'),
(6, 'Vijay', 'Engineering', 78000.00, '2019-05-22'),
(7, 'Veena', 'HR', 62000.00, '2023-03-12'),
(8, 'Meena', 'Marketing', 65000.00, '2022-08-18');

# %%
# %sql
select * from Employee
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE TABLE Sales (
sales_id INT PRIMARY KEY,
emp_id INT,
product VARCHAR(50),
amount DECIMAL(10, 2),
sale_date DATE
);

# %%
# %sql
INSERT INTO Sales (sales_id, emp_id, product, amount, sale_date) VALUES
(1, 1, 'Laptop', 50000.00, '2023-01-15'),
(2, 2, 'Mobile', 30000.00, '2023-02-18'),
(3, 3, 'Tablet', 20000.00, '2023-02-25'),
(4, 4, 'Laptop', 45000.00, '2023-03-05'),
(5, 5, 'Mobile', 35000.00, '2023-03-12'),
(6, 6, 'Tablet', 25000.00, '2023-03-20'),
(7, 7, 'Laptop', 60000.00, '2023-04-01'),
(8, 8, 'Mobile', 40000.00, '2023-04-10');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

# %%
# %sql
select * from sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select department,sum(salary)  from Employee group by department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>sum(salary)</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,count(emp_id) from Employee group by department
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# File <command-8264562721678013>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'select department,count(emp_id) from Employee group by department\nselect department,avg(salary) from Employee group by department\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
select department,avg(salary) from Employee group by department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>avg(salary)</th></tr></thead><tbody><tr><td>HR</td><td>59000.000000</td></tr><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Engineering</td><td>76500.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

# %%
# %sql
select department,max(salary) from Employee group by department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max(salary)</th></tr></thead><tbody><tr><td>HR</td><td>62000.00</td></tr><tr><td>Finance</td><td>80000.00</td></tr><tr><td>Engineering</td><td>78000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,min(salary) from Employee group by department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>min(salary)</th></tr></thead><tbody><tr><td>HR</td><td>55000.00</td></tr><tr><td>Finance</td><td>70000.00</td></tr><tr><td>Engineering</td><td>75000.00</td></tr><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,sum(salary) as total from Employee group by department having total>100000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,count(emp_id) as c from Employee group by department having c>2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>c</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select emp_id,avg(salary),department from Employee  where joining_date>'2021-01-01' group by department,emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>avg(salary)</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>60000.000000</td><td>HR</td></tr><tr><td>2</td><td>70000.000000</td><td>Finance</td></tr><tr><td>3</td><td>55000.000000</td><td>HR</td></tr><tr><td>4</td><td>80000.000000</td><td>Finance</td></tr><tr><td>7</td><td>62000.000000</td><td>HR</td></tr><tr><td>8</td><td>65000.000000</td><td>Marketing</td></tr></tbody></table></div>

# %%
# %sql
select department,sum(salary) as total from Employee group by department having total>75000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,sum(salary) as total from Employee group by department having total<150000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>Marketing</td><td>65000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,count(emp_id) as c from employee group by department having c>1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>c</th></tr></thead><tbody><tr><td>HR</td><td>3</td></tr><tr><td>Finance</td><td>2</td></tr><tr><td>Engineering</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select department,sum(salary) as total from Employee group by department having total>125000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

# %%
# %sql
select department,avg(salary) as total from Employee group by department having total>60000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>Finance</td><td>75000.000000</td></tr><tr><td>Engineering</td><td>76500.000000</td></tr><tr><td>Marketing</td><td>65000.000000</td></tr></tbody></table></div>

# %%
# %sql
select department,sum(salary) as total from Employee group by department having total between 100000 and 200000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total</th></tr></thead><tbody><tr><td>HR</td><td>177000.00</td></tr><tr><td>Finance</td><td>150000.00</td></tr><tr><td>Engineering</td><td>153000.00</td></tr></tbody></table></div>

# %%
# %sql
select * from Employee
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from Sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from sales s join employee e on s.emp_id =e.emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select emp_id, sum(amount) as total_sales 
from Sales 
group by emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>total_sales</th></tr></thead><tbody><tr><td>1</td><td>50000.00</td></tr><tr><td>2</td><td>30000.00</td></tr><tr><td>3</td><td>20000.00</td></tr><tr><td>4</td><td>45000.00</td></tr><tr><td>5</td><td>35000.00</td></tr><tr><td>6</td><td>25000.00</td></tr><tr><td>7</td><td>60000.00</td></tr><tr><td>8</td><td>40000.00</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_id, count(s.sales_id) from sales s join employee e on s.emp_id = e.emp_id group by e.emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>count(s.sales_id)</th></tr></thead><tbody><tr><td>5</td><td>1</td></tr><tr><td>1</td><td>1</td></tr><tr><td>3</td><td>1</td></tr><tr><td>2</td><td>1</td></tr><tr><td>6</td><td>1</td></tr><tr><td>7</td><td>1</td></tr><tr><td>4</td><td>1</td></tr><tr><td>8</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select product,sum(amount) from sales group by product
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>sum(amount)</th></tr></thead><tbody><tr><td>Laptop</td><td>155000.00</td></tr><tr><td>Mobile</td><td>105000.00</td></tr><tr><td>Tablet</td><td>45000.00</td></tr></tbody></table></div>

# %%
# %sql
insert into Sales values (9,1,'Laptop',55000,'2023-04-15');
insert into Sales values (10,1,'Mobile',20000,'2023-04-20');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_name ,count(s.sales_id) as sales_count from sales s join employee e on e.emp_id=s.emp_id group by e.emp_name having sales_count>1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>sales_count</th></tr></thead><tbody><tr><td>Karthik</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_id,sum(e.salary),sum(s.amount) from employee e join sales s on e.emp_id=s.emp_id group by e.emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>sum(e.salary)</th><th>sum(s.amount)</th></tr></thead><tbody><tr><td>5</td><td>75000.00</td><td>35000.00</td></tr><tr><td>1</td><td>180000.00</td><td>125000.00</td></tr><tr><td>3</td><td>55000.00</td><td>20000.00</td></tr><tr><td>2</td><td>70000.00</td><td>30000.00</td></tr><tr><td>6</td><td>78000.00</td><td>25000.00</td></tr><tr><td>7</td><td>62000.00</td><td>60000.00</td></tr><tr><td>4</td><td>80000.00</td><td>45000.00</td></tr><tr><td>8</td><td>65000.00</td><td>40000.00</td></tr></tbody></table></div>

# %%
# %sql
select emp_id ,count(distinct product) from sales group by emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>count(DISTINCTproduct)</th></tr></thead><tbody><tr><td>5</td><td>1</td></tr><tr><td>1</td><td>2</td></tr><tr><td>3</td><td>1</td></tr><tr><td>2</td><td>1</td></tr><tr><td>6</td><td>1</td></tr><tr><td>7</td><td>1</td></tr><tr><td>4</td><td>1</td></tr><tr><td>8</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select emp_id,max(amount) from sales group by emp_id
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>max(amount)</th></tr></thead><tbody><tr><td>5</td><td>35000.00</td></tr><tr><td>1</td><td>55000.00</td></tr><tr><td>3</td><td>20000.00</td></tr><tr><td>2</td><td>30000.00</td></tr><tr><td>6</td><td>25000.00</td></tr><tr><td>7</td><td>60000.00</td></tr><tr><td>4</td><td>45000.00</td></tr><tr><td>8</td><td>40000.00</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_name ,sum(e.salary),sum(s.amount) from employee e join sales s on e.emp_id=s.emp_id group by e.emp_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>sum(e.salary)</th><th>sum(s.amount)</th></tr></thead><tbody><tr><td>Veena</td><td>62000.00</td><td>60000.00</td></tr><tr><td>Meena</td><td>65000.00</td><td>40000.00</td></tr><tr><td>Karthik</td><td>180000.00</td><td>125000.00</td></tr><tr><td>Vijay</td><td>78000.00</td><td>25000.00</td></tr><tr><td>Veer</td><td>55000.00</td><td>20000.00</td></tr><tr><td>Ajay</td><td>75000.00</td><td>35000.00</td></tr><tr><td>Pratik</td><td>70000.00</td><td>30000.00</td></tr><tr><td>Priya</td><td>80000.00</td><td>45000.00</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_name,count(distinct s.product) from employee e join sales s on e.emp_id=s.emp_id group by e.emp_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>count(DISTINCTs.product)</th></tr></thead><tbody><tr><td>Veena</td><td>1</td></tr><tr><td>Meena</td><td>1</td></tr><tr><td>Karthik</td><td>2</td></tr><tr><td>Vijay</td><td>1</td></tr><tr><td>Veer</td><td>1</td></tr><tr><td>Ajay</td><td>1</td></tr><tr><td>Priya</td><td>1</td></tr><tr><td>Pratik</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_name, max(s.amount) from employees e join sales s on e.emp_id=s.emp_id group by e.emp_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>max(s.amount)</th></tr></thead><tbody><tr><td>Meena</td><td>35000.00</td></tr><tr><td>Karthik</td><td>55000.00</td></tr><tr><td>Vijay</td><td>20000.00</td></tr><tr><td>Veer</td><td>25000.00</td></tr><tr><td>Keerthi</td><td>60000.00</td></tr><tr><td>Vinay</td><td>45000.00</td></tr><tr><td>Ajay</td><td>30000.00</td></tr><tr><td>Priya</td><td>40000.00</td></tr></tbody></table></div>

# %%
# %sql
select product,sum(amount) as total from sales group by product having total>50000
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>total</th></tr></thead><tbody><tr><td>Mobile</td><td>125000.00</td></tr><tr><td>Laptop</td><td>210000.00</td></tr></tbody></table></div>

# %%
# %sql
select e.department ,max(s.amount) from employee e join sales s on e.emp_id=s.emp_id group by e.department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>max(s.amount)</th></tr></thead><tbody><tr><td>Engineering</td><td>35000.00</td></tr><tr><td>HR</td><td>60000.00</td></tr><tr><td>Finance</td><td>45000.00</td></tr><tr><td>Marketing</td><td>40000.00</td></tr></tbody></table></div>

# %%
# %sql

select e.department, sum(s.amount) as total_sales
from Employee e
join Sales s
on e.emp_id = s.emp_id
group by e.department
order by total_sales desc
limit 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total_sales</th></tr></thead><tbody><tr><td>HR</td><td>205000.00</td></tr></tbody></table></div>

# %%
# %sql
select e.emp_name,sum(s.amount) as total from employee e join sales s on e.emp_id=s.emp_id group by e.emp_name order by total desc limit 3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>total</th></tr></thead><tbody><tr><td>Karthik</td><td>125000.00</td></tr><tr><td>Veena</td><td>60000.00</td></tr><tr><td>Priya</td><td>45000.00</td></tr></tbody></table></div>

# %%
# %sql
select year(joining_date) as year_j ,count(emp_id) as total ,avg(salary)from employee  group by year_j
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year_j</th><th>total</th><th>avg(salary)</th></tr></thead><tbody><tr><td>2021</td><td>3</td><td>61666.666667</td></tr><tr><td>2022</td><td>2</td><td>72500.000000</td></tr><tr><td>2020</td><td>1</td><td>75000.000000</td></tr><tr><td>2019</td><td>1</td><td>78000.000000</td></tr><tr><td>2023</td><td>1</td><td>62000.000000</td></tr></tbody></table></div>

# %%
# %sql
select e.department, count(e.emp_id) as no_sales_employees
from Employee e
left join Sales s
on e.emp_id = s.emp_id
where s.emp_id is null
group by e.department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>no_sales_employees</th></tr></thead><tbody></tbody></table></div>
